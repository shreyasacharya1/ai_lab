# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyasacharya1/ai_lab/blob/main/resolution_first_order.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Shreyas.R.Achar 1BM23CS320")
from copy import deepcopy

# ------------------------------
# Utility functions
# ------------------------------
def substitute(clause, subs):
    """Apply substitutions to a clause."""
    new_clause = []
    for literal in clause:
        pred, args, neg = literal
        new_args = []
        for a in args:
            if a in subs:
                new_args.append(subs[a])
            else:
                new_args.append(a)
        new_clause.append((pred, new_args, neg))
    return new_clause

def unify(x, y, subs=None):
    """Unify two literals/terms."""
    if subs is None:
        subs = {}
    if x == y:
        return subs
    if isinstance(x, str) and x[0].islower():
        return unify_var(x, y, subs)
    elif isinstance(y, str) and y[0].islower():
        return unify_var(y, x, subs)
    elif isinstance(x, tuple) and isinstance(y, tuple):
        if x[0] != y[0] or len(x[1]) != len(y[1]):
            return None
        for a, b in zip(x[1], y[1]):
            subs = unify(a, b, subs)
            if subs is None:
                return None
        return subs
    else:
        return None

def unify_var(var, x, subs):
    if var in subs:
        return unify(subs[var], x, subs)
    elif x in subs:
        return unify(var, subs[x], subs)
    elif occur_check(var, x, subs):
        return None
    else:
        subs[var] = x
        return subs

def occur_check(var, x, subs):
    if var == x:
        return True
    elif isinstance(x, str) and x in subs:
        return occur_check(var, subs[x], subs)
    elif isinstance(x, tuple):
        return any(occur_check(var, arg, subs) for arg in x[1])
    return False


# ------------------------------
# Resolution core
# ------------------------------
def resolve(clause1, clause2):
    """Try all pairs of literals to resolve."""
    resolvents = []
    for lit1 in clause1:
        for lit2 in clause2:
            if lit1[0] == lit2[0] and lit1[2] != lit2[2]:  # same predicate, opposite polarity
                subs = unify(tuple(lit1[:2]), tuple(lit2[:2]))
                if subs is not None:
                    new_c1 = substitute(clause1, subs)
                    new_c2 = substitute(clause2, subs)
                    new_clause = [l for l in new_c1 if l != lit1] + [l for l in new_c2 if l != lit2]
                    # remove duplicates
                    new_clause = [x for i, x in enumerate(new_clause) if x not in new_clause[:i]]
                    resolvents.append(new_clause)
    return resolvents


def pl_resolution(kb, query):
    clauses = deepcopy(kb)
    # add negated query
    neg_query = [(query[0], query[1], not query[2])]
    clauses.append(neg_query)

    print("Initial clauses:")
    for i, c in enumerate(clauses):
        print(f"C{i+1}: {pretty_clause(c)}")
    print("\nResolution steps:\n")

    new = []
    while True:
        n = len(clauses)
        pairs = [(clauses[i], clauses[j]) for i in range(n) for j in range(i + 1, n)]
        for (ci, cj) in pairs:
            resolvents = resolve(ci, cj)
            for r in resolvents:
                if not r:
                    print("Derived empty clause {} -> CONTRADICTION.".format(pretty_clause(r)))
                    return True
                if r not in clauses and r not in new:
                    new.append(r)
                    print(f"Resolved {pretty_clause(ci)} and {pretty_clause(cj)} -> {pretty_clause(r)}")
        if all(r in clauses for r in new):
            return False
        clauses.extend(new)


# ------------------------------
# Pretty printer
# ------------------------------
def pretty_clause(clause):
    if not clause:
        return "{}"
    out = []
    for pred, args, neg in clause:
        s = f"{pred}({', '.join(args)})"
        if neg:
            s = "¬" + s
        out.append(s)
    return " ∨ ".join(out)


# ------------------------------
# Example Knowledge Base
# ------------------------------
if __name__ == "__main__":
    # KB Clauses:
    # 1. ¬parent(x,y) ∨ ancestor(x,y)
    # 2. ¬ancestor(x,y) ∨ ¬ancestor(y,z) ∨ ancestor(x,z)
    # 3. parent(tom,bob)
    # 4. parent(bob,alice)
    KB = [
        [('parent', ['x', 'y'], True), ('ancestor', ['x', 'y'], False)],
        [('ancestor', ['x', 'y'], True), ('ancestor', ['y', 'z'], True), ('ancestor', ['x', 'z'], False)],
        [('parent', ['tom', 'bob'], False)],
        [('parent', ['bob', 'alice'], False)]
    ]

    # Query: ancestor(tom, alice)
    QUERY = ('ancestor', ['tom', 'alice'], False)

    result = pl_resolution(KB, QUERY)
    print("\nResult:", "PROVED ✅" if result else "NOT PROVABLE ❌")
# Out:
# Streaming output truncated to the last 5000 lines.
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬parent(y, z) ∨ ancestor(y, z) -> ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(z, alice) ∨ ¬parent(z, y) ∨ ¬ancestor(y, z) ∨ ¬parent(y, z) ∨ ancestor(y, z)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬parent(y, z) ∨ ancestor(y, z) -> ¬ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, alice) ∨ ¬parent(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬parent(y, z) ∨ ancestor(y, z) -> ¬ancestor(y, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(y, z) ∨ ¬parent(bob, z) ∨ ¬parent(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(x, x) ∨ ancestor(x, x) ∨ ¬parent(x, x) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, x) ∨ ¬parent(tom, x)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬parent(bob, bob) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(x, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(bob, bob)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ¬parent(tom, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) -> ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, alice) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ¬parent(tom, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ¬ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) -> ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, alice) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ¬ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(tom, tom) ∨ ¬ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, tom) ∨ ancestor(tom, tom) ∨ ¬parent(bob, tom) ∨ ¬parent(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) ∨ ¬parent(y, alice) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(y, bob) ∨ ¬ancestor(bob, y) ∨ ancestor(y, y) ∨ ¬parent(bob, y) ∨ ¬parent(tom, y) ∨ ancestor(tom, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(y, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(y, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(x, y) ∨ ¬ancestor(y, alice) ∨ ancestor(x, alice) ∨ ¬parent(y, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(y, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(y, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, y) ∨ ancestor(tom, y) ∨ ¬parent(bob, y) ∨ ¬parent(y, y) ∨ ¬ancestor(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(y, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(y, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(x, y) ∨ ¬ancestor(y, tom) ∨ ancestor(x, tom) ∨ ¬parent(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬parent(bob, bob) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, tom) ∨ ancestor(tom, tom) ∨ ¬parent(bob, tom) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(y, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(y, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(alice, alice) ∨ ancestor(alice, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(y, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(y, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, y) ∨ ¬ancestor(y, tom) ∨ ancestor(x, tom) ∨ ¬parent(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, tom) ∨ ancestor(tom, tom) ∨ ¬parent(bob, tom) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬parent(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(x, tom) ∨ ¬parent(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(alice, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(alice, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, y) ∨ ancestor(tom, y) ∨ ¬parent(bob, y) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(y, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(y, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, y) ∨ ¬ancestor(y, tom) ∨ ancestor(x, tom) ∨ ¬parent(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, tom) ∨ ancestor(tom, tom) ∨ ¬parent(bob, tom) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, tom)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(alice, bob) ∨ ¬ancestor(bob, y) ∨ ancestor(alice, y) ∨ ¬parent(bob, y) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(y, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(y, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(y, y) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ¬ancestor(y, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(y, y) -> ¬ancestor(y, bob) ∨ ¬ancestor(bob, y) ∨ ancestor(y, y) ∨ ¬parent(bob, y) ∨ ¬parent(y, y)
# Resolved ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, y) ∨ ancestor(tom, y) ∨ ¬parent(bob, y) ∨ ¬parent(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(alice, alice) -> ¬ancestor(alice, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(alice, z) ∨ ¬parent(alice, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) -> ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬ancestor(x, tom) ∨ ancestor(x, x) ∨ ¬ancestor(tom, tom)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, tom)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(y, alice) ∨ ¬ancestor(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, alice) ∨ parent(bob, alice) ∨ ¬parent(alice, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(bob, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(bob, z) ∨ ¬parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and parent(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ parent(tom, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and parent(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ancestor(bob, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬ancestor(tom, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, x) ∨ ¬ancestor(x, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, x) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, alice) ∨ ¬parent(x, tom) ∨ ancestor(x, bob) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(x, z) ∨ ¬parent(x, alice) ∨ ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬parent(x, bob) ∨ ¬ancestor(bob, x) ∨ ancestor(x, x) ∨ ¬parent(bob, x)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) -> ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬parent(x, tom) ∨ ancestor(x, x) ∨ ¬ancestor(tom, tom)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, tom)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(y, y) ∨ ¬parent(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(y, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, y) ∨ ¬parent(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(y, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, y) ∨ ¬parent(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(y, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(y, z) ∨ ¬parent(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, y) ∨ ¬parent(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(alice, alice) ∨ ancestor(alice, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, y) ∨ ¬parent(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(alice, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, y) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, y) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(y, y) ∨ ¬parent(y, alice) ∨ ¬parent(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(alice, alice) -> ¬ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(z, z) ∨ ¬ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(alice, alice) -> ¬ancestor(alice, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(alice, z) ∨ ¬parent(tom, z) ∨ ¬ancestor(z, z) ∨ ancestor(tom, z)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) ∨ ¬parent(y, alice) ∨ ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ancestor(y, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, y) ∨ ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(alice, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ancestor(tom, bob) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, alice) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) ∨ parent(bob, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and parent(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and parent(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) ∨ parent(tom, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and parent(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ancestor(bob, alice) -> ¬ancestor(bob, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(bob, alice) ∨ ¬parent(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬ancestor(bob, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(x, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(bob, bob)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, alice) ∨ ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(bob, bob) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) ∨ ¬parent(y, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ancestor(y, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(alice, y) ∨ ¬ancestor(y, y) ∨ ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, y) ∨ ¬parent(y, y) ∨ ¬ancestor(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(y, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(y, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬parent(bob, bob)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬ancestor(x, y) ∨ ¬ancestor(y, y) ∨ ancestor(x, y) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, y) ∨ ¬ancestor(y, bob) ∨ ancestor(x, bob) ∨ ¬parent(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬ancestor(bob, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(bob, bob) ∨ ¬parent(tom, bob) ∨ ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬parent(bob, bob)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, y) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(alice, alice) ∨ ancestor(alice, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, tom)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(alice, alice) -> ¬ancestor(alice, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(alice, y) ∨ ¬parent(tom, y) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(y, y) -> ¬ancestor(y, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(y, y) ∨ ¬parent(tom, y) ∨ ¬parent(y, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, y) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) ∨ ¬parent(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬parent(tom, alice) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, alice) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, y) ∨ ¬parent(y, y) ∨ ancestor(y, y)
# Resolved ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(alice, alice) and ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(x, z) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(x, x)
# ...
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(y, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(y, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice) -> ¬parent(alice, y) ∨ ancestor(alice, y) ∨ ¬ancestor(y, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(y, alice) ∨ ¬parent(bob, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice) ∨ ¬ancestor(y, y) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(y, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(y, bob) ∨ ¬ancestor(bob, y) ∨ ancestor(y, y) ∨ ¬parent(bob, y) ∨ ¬parent(y, y) -> ¬parent(bob, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, bob) ∨ ancestor(y, y) ∨ ¬parent(y, y)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, y) ∨ ancestor(tom, y) ∨ ¬parent(bob, y) ∨ ¬parent(y, y) ∨ ancestor(y, y) -> ¬parent(bob, y) ∨ ancestor(bob, y) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, y) ∨ ¬parent(y, y) ∨ ancestor(y, y)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬ancestor(x, tom) ∨ ancestor(x, x) ∨ ¬ancestor(tom, tom) -> ¬parent(x, x) ∨ ancestor(x, x) ∨ ¬ancestor(tom, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬ancestor(x, tom) ∨ ¬ancestor(tom, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬ancestor(x, tom) ∨ ancestor(x, x) ∨ ¬ancestor(tom, tom) -> ¬parent(x, tom) ∨ ancestor(x, tom) ∨ ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ancestor(x, x) ∨ ¬ancestor(tom, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) -> ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) -> ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) -> ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom) -> ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, tom) -> ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, tom) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) -> ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬ancestor(tom, z)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) -> ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(tom, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) -> ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, y) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, y)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, y) -> ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(y, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, alice) ∨ parent(bob, alice) ∨ ¬parent(alice, alice) -> ¬parent(bob, alice) ∨ ancestor(bob, alice) ∨ ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, alice) ∨ ¬parent(alice, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, alice) ∨ parent(bob, alice) ∨ ¬parent(alice, alice) -> ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, alice) ∨ parent(bob, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(bob, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(bob, z) ∨ ¬parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ¬ancestor(bob, alice) ∨ ancestor(bob, z) ∨ ¬parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ parent(tom, alice) -> ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ parent(tom, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ancestor(tom, alice) -> ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, z) ∨ ancestor(tom, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob) ∨ ancestor(bob, bob) -> ¬parent(tom, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, bob) -> ¬parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(alice, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, bob) -> ¬parent(alice, bob) ∨ ancestor(alice, bob) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, bob) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, x) ∨ ¬ancestor(x, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, x) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ¬parent(tom, bob) -> ¬parent(x, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(tom, x) ∨ ancestor(tom, bob) ∨ ¬parent(tom, x) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, bob) ∨ ¬parent(tom, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, alice) ∨ ¬parent(x, tom) ∨ ancestor(x, bob) ∨ ¬parent(tom, bob) -> ¬parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(alice, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, alice) ∨ ¬parent(x, tom) ∨ ancestor(x, bob) ∨ ¬parent(tom, bob) -> ¬parent(alice, bob) ∨ ancestor(alice, bob) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, bob) ∨ ¬parent(tom, alice) ∨ ¬parent(alice, tom) ∨ ¬parent(tom, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(x, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(x, z) ∨ ¬parent(x, alice) ∨ ¬parent(x, bob) ∨ ¬ancestor(bob, alice) ∨ ¬parent(bob, alice) -> ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ¬ancestor(alice, alice) ∨ ¬parent(alice, alice) ∨ ¬parent(alice, bob) ∨ ¬ancestor(bob, alice) ∨ ¬parent(bob, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬parent(x, bob) ∨ ¬ancestor(bob, x) ∨ ancestor(x, x) ∨ ¬parent(bob, x) -> ¬parent(x, x) ∨ ancestor(x, x) ∨ ¬ancestor(tom, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬parent(x, bob) ∨ ¬ancestor(bob, x) ∨ ¬parent(bob, x)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬parent(x, tom) ∨ ancestor(x, x) ∨ ¬ancestor(tom, tom) -> ¬parent(x, x) ∨ ancestor(x, x) ∨ ¬ancestor(tom, x) ∨ ancestor(tom, x) ∨ ¬parent(tom, x) ∨ ¬parent(x, tom) ∨ ¬ancestor(tom, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) -> ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, alice) -> ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, tom) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(y, y) ∨ ¬parent(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, alice) -> ¬parent(alice, y) ∨ ancestor(alice, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, y) ∨ ¬parent(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) -> ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬ancestor(tom, z)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) -> ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(alice, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(tom, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(tom, y) -> ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬parent(tom, alice) ∨ ¬parent(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, y) -> ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(y, y) ∨ ¬ancestor(y, tom) ∨ ancestor(y, tom)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(z, z) ∨ ¬parent(z, z) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(alice, tom) ∨ ancestor(tom, tom) ∨ ¬parent(alice, tom) ∨ ancestor(alice, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(tom, alice) ∨ ¬ancestor(alice, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬parent(alice, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, tom) ∨ ¬parent(tom, alice) ∨ ¬parent(tom, tom) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
# Resolved ¬parent(x, y) ∨ ancestor(x, y) and ¬ancestor(y, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(y, z) ∨ ¬parent(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) -> ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(bob, z) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob)
