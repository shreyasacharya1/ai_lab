# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyasacharya1/ai_lab/blob/main/resolution_first_order.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Shreyas.R.Achar 1BM23CS320")
from copy import deepcopy

# ------------------------------
# Utility functions
# ------------------------------
def substitute(clause, subs):
    """Apply substitutions to a clause."""
    new_clause = []
    for literal in clause:
        pred, args, neg = literal
        new_args = []
        for a in args:
            if a in subs:
                new_args.append(subs[a])
            else:
                new_args.append(a)
        new_clause.append((pred, new_args, neg))
    return new_clause

def unify(x, y, subs=None):
    """Unify two literals/terms."""
    if subs is None:
        subs = {}
    if x == y:
        return subs
    if isinstance(x, str) and x[0].islower():
        return unify_var(x, y, subs)
    elif isinstance(y, str) and y[0].islower():
        return unify_var(y, x, subs)
    elif isinstance(x, tuple) and isinstance(y, tuple):
        if x[0] != y[0] or len(x[1]) != len(y[1]):
            return None
        for a, b in zip(x[1], y[1]):
            subs = unify(a, b, subs)
            if subs is None:
                return None
        return subs
    else:
        return None

def unify_var(var, x, subs):
    if var in subs:
        return unify(subs[var], x, subs)
    elif x in subs:
        return unify(var, subs[x], subs)
    elif occur_check(var, x, subs):
        return None
    else:
        subs[var] = x
        return subs

def occur_check(var, x, subs):
    if var == x:
        return True
    elif isinstance(x, str) and x in subs:
        return occur_check(var, subs[x], subs)
    elif isinstance(x, tuple):
        return any(occur_check(var, arg, subs) for arg in x[1])
    return False


# ------------------------------
# Resolution core
# ------------------------------
def resolve(clause1, clause2):
    """Try all pairs of literals to resolve."""
    resolvents = []
    for lit1 in clause1:
        for lit2 in clause2:
            if lit1[0] == lit2[0] and lit1[2] != lit2[2]:  # same predicate, opposite polarity
                subs = unify(tuple(lit1[:2]), tuple(lit2[:2]))
                if subs is not None:
                    new_c1 = substitute(clause1, subs)
                    new_c2 = substitute(clause2, subs)
                    new_clause = [l for l in new_c1 if l != lit1] + [l for l in new_c2 if l != lit2]
                    # remove duplicates
                    new_clause = [x for i, x in enumerate(new_clause) if x not in new_clause[:i]]
                    resolvents.append(new_clause)
    return resolvents


def pl_resolution(kb, query):
    clauses = deepcopy(kb)
    # add negated query
    neg_query = [(query[0], query[1], not query[2])]
    clauses.append(neg_query)

    print("Initial clauses:")
    for i, c in enumerate(clauses):
        print(f"C{i+1}: {pretty_clause(c)}")
    print("\nResolution steps:\n")

    new = []
    while True:
        n = len(clauses)
        pairs = [(clauses[i], clauses[j]) for i in range(n) for j in range(i + 1, n)]
        for (ci, cj) in pairs:
            resolvents = resolve(ci, cj)
            for r in resolvents:
                if not r:
                    print("Derived empty clause {} -> CONTRADICTION.".format(pretty_clause(r)))
                    return True
                if r not in clauses and r not in new:
                    new.append(r)
                    print(f"Resolved {pretty_clause(ci)} and {pretty_clause(cj)} -> {pretty_clause(r)}")
        if all(r in clauses for r in new):
            return False
        clauses.extend(new)


# ------------------------------
# Pretty printer
# ------------------------------
def pretty_clause(clause):
    if not clause:
        return "{}"
    out = []
    for pred, args, neg in clause:
        s = f"{pred}({', '.join(args)})"
        if neg:
            s = "¬" + s
        out.append(s)
    return " ∨ ".join(out)


# ------------------------------
# Example Knowledge Base
# ------------------------------
if __name__ == "__main__":
    # KB Clauses:
    # 1. ¬parent(x,y) ∨ ancestor(x,y)
    # 2. ¬ancestor(x,y) ∨ ¬ancestor(y,z) ∨ ancestor(x,z)
    # 3. parent(tom,bob)
    # 4. parent(bob,alice)
    KB = [
        [('parent', ['x', 'y'], True), ('ancestor', ['x', 'y'], False)],
        [('ancestor', ['x', 'y'], True), ('ancestor', ['y', 'z'], True), ('ancestor', ['x', 'z'], False)],
        [('parent', ['tom', 'bob'], False)],
        [('parent', ['bob', 'alice'], False)]
    ]

    # Query: ancestor(tom, alice)
    QUERY = ('ancestor', ['tom', 'alice'], False)

    result = pl_resolution(KB, QUERY)
    print("\nResult:", "PROVED ✅" if result else "NOT PROVABLE ❌")
# Out:
# Streaming output truncated to the last 5000 lines.
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, y) ∨ ¬ancestor(y, y) ∨ ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ parent(y, z) ∨ ancestor(y, z) -> ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ancestor(z, z) ∨ parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, y) ∨ ¬ancestor(y, y) ∨ ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ parent(y, z) ∨ ancestor(y, z) -> ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬ancestor(z, y) ∨ ¬ancestor(y, y) ∨ ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, y) ∨ ¬ancestor(y, y) ∨ ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ parent(y, z) ∨ ancestor(y, z) -> ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, y) ∨ ancestor(z, y) ∨ ancestor(z, z) ∨ parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(tom, z) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) -> ¬ancestor(bob, y) ∨ ¬ancestor(y, bob) ∨ ancestor(bob, bob) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) -> ¬ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob) -> ¬ancestor(bob, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(bob, z) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob) -> ¬ancestor(bob, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(bob, z) ∨ ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob) -> ¬ancestor(bob, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(bob, z) ∨ ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob) -> ¬ancestor(x, bob) ∨ ¬ancestor(bob, tom) ∨ ancestor(x, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob) -> ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob) -> ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob) -> ¬ancestor(bob, y) ∨ ¬ancestor(y, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(bob, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(bob, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(bob, tom) ∨ ancestor(bob, alice) ∨ ancestor(bob, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice) -> ¬ancestor(alice, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(alice, z) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice) -> ¬ancestor(alice, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(alice, z) ∨ ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, tom) ∨ ancestor(x, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice) -> ¬ancestor(alice, y) ∨ ¬ancestor(y, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(alice, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(alice, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(alice, tom) ∨ ancestor(alice, alice) ∨ parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, alice) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ parent(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, alice) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, alice) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ parent(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ parent(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, tom) ∨ ¬parent(tom, tom) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, tom) ∨ ¬parent(tom, tom)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, tom) ∨ ¬parent(tom, tom) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ parent(tom, tom) ∨ ¬parent(tom, tom)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, tom) ∨ ¬parent(tom, tom) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, tom) ∨ ¬parent(tom, tom)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, tom) ∨ ¬parent(tom, tom) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ parent(tom, tom) ∨ ¬parent(tom, tom)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ parent(tom, tom) ∨ ¬parent(tom, tom) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ parent(tom, tom) ∨ ¬parent(tom, tom)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(tom, z) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice) -> ¬ancestor(alice, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(alice, z) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice) -> ¬ancestor(bob, y) ∨ ¬ancestor(y, bob) ∨ ancestor(bob, bob) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice) -> ¬ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ancestor(tom, alice) ∨ ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(x, z) ∨ ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ¬parent(x, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z) -> ¬ancestor(x, x) ∨ ¬ancestor(x, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z) -> ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(x, z) ∨ ¬parent(x, z) -> ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(x, z) ∨ ¬parent(x, z) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(alice, z) ∨ ¬ancestor(z, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(y, z) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(x, z) ∨ ¬parent(x, z) -> ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(x, z) ∨ ¬parent(x, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(x, z) ∨ ¬parent(x, z) -> ¬ancestor(x, y) ∨ ¬ancestor(y, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(x, alice) ∨ ¬parent(x, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(x, z) ∨ ¬parent(x, z) -> ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(x, z) ∨ ¬parent(x, z) -> ¬ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(x, z) ∨ ¬parent(x, z) -> ¬ancestor(z, y) ∨ ¬ancestor(y, alice) ∨ ancestor(z, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(x, z) ∨ ¬parent(x, z) -> ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(x, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(x, z) ∨ ¬parent(x, y) -> ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ¬ancestor(x, z) ∨ ¬parent(x, y)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(x, z) ∨ ¬parent(x, y) -> ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ancestor(y, z) ∨ ¬parent(x, y)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) -> ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(alice, z) ∨ ¬ancestor(z, alice) ∨ ancestor(alice, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) -> ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) -> ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) -> ¬ancestor(z, y) ∨ ¬ancestor(y, alice) ∨ ancestor(z, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) ∨ ¬parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬parent(y, z) ∨ ¬ancestor(z, z) -> ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ¬parent(y, z) ∨ ¬ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬parent(y, z) ∨ ¬ancestor(z, z) -> ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ancestor(y, y) ∨ ¬parent(y, z) ∨ ¬ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬parent(y, z) ∨ ¬ancestor(z, z) -> ¬ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ancestor(y, z) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, y) ∨ ¬ancestor(y, y) ∨ ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬parent(y, z) -> ¬ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬ancestor(y, y) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(tom, z) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob) -> ¬ancestor(bob, y) ∨ ¬ancestor(y, bob) ∨ ancestor(bob, bob) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob) -> ¬ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬ancestor(tom, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(tom, bob) ∨ ancestor(tom, alice) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, z) ∨ ancestor(tom, z) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(x, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, bob) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(y, y) ∨ ¬ancestor(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ancestor(tom, bob) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, y) ∨ ¬ancestor(y, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(bob, y) ∨ ¬ancestor(y, z) ∨ ancestor(bob, z) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, y) ∨ ¬ancestor(y, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, y) ∨ ¬ancestor(y, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(bob, bob) ∨ ancestor(bob, bob) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, y) ∨ ¬ancestor(y, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(bob, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(bob, y) ∨ ¬ancestor(y, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice) -> ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(bob, y) ∨ ancestor(bob, y) ∨ ancestor(bob, alice) ∨ ¬parent(bob, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice) -> ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(tom, y) ∨ ¬ancestor(y, alice) ∨ ancestor(tom, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, alice) -> ¬ancestor(x, y) ∨ ¬ancestor(y, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z) ∨ ¬parent(z, z) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(x, z) ∨ ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ¬parent(x, z) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z) ∨ ¬parent(z, z) -> ¬ancestor(x, x) ∨ ¬ancestor(x, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z) ∨ ¬parent(z, z) -> ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, z) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(tom, z) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, tom) ∨ ancestor(z, z) ∨ ¬parent(tom, z) ∨ ¬ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(z, tom) ∨ ancestor(z, z) ∨ ¬parent(tom, z) ∨ ¬ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(tom, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, x) ∨ ancestor(x, x) ∨ ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(x, x)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ¬parent(alice, x) ∨ ancestor(alice, alice) ∨ ¬parent(x, alice) ∨ ¬ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ¬parent(x, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(x, y) ∨ ¬ancestor(y, x) ∨ ancestor(x, x) ∨ ¬ancestor(tom, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(x, x)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(x, y) ∨ ¬ancestor(y, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ancestor(tom, alice) ∨ ¬parent(alice, x) ∨ ancestor(alice, alice) ∨ ¬parent(x, alice) ∨ ¬ancestor(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬ancestor(tom, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(x, z) ∨ ancestor(x, z) ∨ ¬parent(z, z) -> ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(x, z) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(x, z) ∨ ancestor(x, z) ∨ ¬parent(z, z) -> ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(x, z) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(x, z) ∨ ancestor(x, z) ∨ ¬parent(z, z) -> ¬ancestor(x, z) ∨ ¬ancestor(z, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(alice, alice) ∨ ¬parent(x, alice) ∨ ¬parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(x, z) ∨ ancestor(x, z) ∨ ¬parent(z, z) -> ¬ancestor(x, x) ∨ ¬ancestor(x, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(x, z) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, alice) ∨ ¬parent(x, z) ∨ ancestor(x, z) ∨ ¬parent(z, z) -> ¬ancestor(z, y) ∨ ¬ancestor(y, alice) ∨ ancestor(z, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(alice, alice) ∨ ¬parent(z, alice) ∨ ¬parent(alice, alice)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, z) ∨ ancestor(tom, z) ∨ ¬parent(x, x) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(tom, z) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, z) ∨ ¬ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, z) ∨ ancestor(tom, z) ∨ ¬parent(x, x) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬parent(tom, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, z) ∨ ancestor(tom, z) ∨ ¬parent(x, x) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, x) ∨ ancestor(x, x) ∨ ¬ancestor(x, x) ∨ ¬parent(x, x)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, z) ∨ ancestor(tom, z) ∨ ¬parent(x, x) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(x, z) ∨ ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, z) ∨ ¬parent(x, x) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, z) ∨ ancestor(tom, z) ∨ ¬parent(x, x) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z) -> ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ancestor(tom, z) ∨ ¬parent(x, x) ∨ ¬parent(x, z) ∨ ¬ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, y) ∨ ¬ancestor(y, y) ∨ ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬parent(x, y) ∨ ancestor(x, z) ∨ ¬parent(y, z) -> ¬ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬ancestor(y, y) ∨ ¬parent(z, y) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, y) ∨ ¬ancestor(y, y) ∨ ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬parent(x, y) ∨ ancestor(x, z) ∨ ¬parent(y, z) -> ¬ancestor(x, x) ∨ ¬ancestor(x, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, x) ∨ ancestor(z, x) ∨ ancestor(z, z) ∨ ¬parent(x, x) ∨ ¬parent(x, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(z, y) ∨ ¬ancestor(y, y) ∨ ancestor(z, y) ∨ ¬ancestor(y, z) ∨ ancestor(z, z) ∨ ¬parent(x, y) ∨ ancestor(x, z) ∨ ¬parent(y, z) -> ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, y) ∨ ancestor(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, y) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z) -> ¬ancestor(y, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(alice, z) ∨ ¬ancestor(z, alice) ∨ ancestor(alice, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z) -> ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z) -> ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(y, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z) -> ¬ancestor(x, z) ∨ ¬ancestor(z, z) ∨ ancestor(x, z) ∨ ¬ancestor(tom, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z) -> ¬ancestor(tom, y) ∨ ¬ancestor(y, z) ∨ ancestor(tom, z) ∨ ¬ancestor(z, z) ∨ ¬ancestor(z, alice) ∨ ancestor(tom, alice) ∨ ¬parent(z, z) ∨ ancestor(z, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, z) ∨ ancestor(tom, z) ∨ ¬parent(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, z) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(x, z) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(z, tom) ∨ ancestor(z, z) ∨ ¬parent(tom, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, z) ∨ ancestor(tom, z) ∨ ¬parent(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, z) -> ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(tom, y) ∨ ancestor(tom, y) ∨ ancestor(tom, z) ∨ ¬parent(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬parent(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, z) -> ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ¬parent(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ¬parent(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, z) -> ¬ancestor(y, y) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) ∨ ancestor(y, y) ∨ ¬parent(z, y) ∨ ancestor(z, z) ∨ ¬parent(y, z)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob) -> ¬ancestor(x, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(x, z) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob) -> ¬ancestor(x, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(x, z) ∨ ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob) -> ¬ancestor(x, x) ∨ ¬ancestor(x, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob) -> ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice) ∨ ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob) -> ¬ancestor(x, y) ∨ ¬ancestor(y, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(x, bob) ∨ ¬ancestor(bob, bob) ∨ ancestor(x, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, x) ∨ ¬parent(x, bob) -> ¬ancestor(bob, y) ∨ ¬ancestor(y, alice) ∨ ancestor(bob, alice) ∨ ¬ancestor(bob, bob) ∨ ancestor(bob, bob) ∨ ¬parent(bob, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(bob, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, tom) ∨ ¬ancestor(tom, z) ∨ ancestor(tom, z) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(bob, bob) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(bob, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(tom, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(tom, z) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, tom) ∨ ¬parent(bob, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(bob, bob) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(bob, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(bob, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(bob, z) ∨ ¬ancestor(tom, bob) ∨ ancestor(tom, bob) ∨ ¬ancestor(bob, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, tom) ∨ ¬parent(tom, bob)
# Resolved ¬ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) and ¬ancestor(tom, x) ∨ ¬ancestor(x, x) ∨ ancestor(tom, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(bob, bob) ∨ ¬parent(tom, bob) -> ¬ancestor(x, tom) ∨ ¬ancestor(tom, x) ∨ ancestor(x, x) ∨ ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(tom, alice) ∨ ¬parent(bob, tom) ∨ ¬ancestor(tom, bob) ∨ ancestor(bob, bob) ∨ ¬parent(tom, bob)
# ...
# Resolved parent(tom, bob) and ¬parent(bob, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, y) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> parent(bob, y) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(bob, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, y) ∨ ¬parent(bob, bob) ∨ ancestor(bob, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> parent(bob, bob) ∨ ¬parent(bob, y) ∨ ancestor(bob, y) ∨ ¬ancestor(y, y) ∨ ancestor(bob, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) -> parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, bob) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice) -> parent(y, bob) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(y, bob) ∨ ¬ancestor(bob, bob) ∨ ¬parent(alice, alice)
# Resolved parent(tom, bob) and ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> parent(tom, tom) ∨ ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) -> parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬parent(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) -> parent(y, y) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬parent(alice, alice)
# Resolved parent(tom, bob) and ¬parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) -> parent(tom, tom) ∨ ¬parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom)
# Resolved parent(tom, bob) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice) -> parent(tom, tom) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(tom, alice)
# Resolved parent(tom, bob) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(alice, alice) -> parent(y, y) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(alice, alice) -> parent(tom, alice) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ancestor(tom, alice) ∨ ¬ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice) -> parent(y, y) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice) -> parent(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) -> parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice) -> parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice) -> parent(y, y) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice) -> parent(tom, tom) ∨ ¬parent(tom, y) ∨ ancestor(tom, y) ∨ ¬ancestor(y, y) ∨ ancestor(tom, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) -> parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice) -> parent(y, y) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬ancestor(alice, y) ∨ ¬ancestor(y, alice)
# Resolved parent(tom, bob) and ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) -> parent(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ancestor(y, alice)
# Resolved parent(tom, bob) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice) -> parent(y, y) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, tom) ∨ ancestor(y, tom) ∨ ¬ancestor(tom, tom) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice) -> parent(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) ∨ ¬ancestor(y, y) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, y) ∨ ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬parent(x, y) ∨ ancestor(x, z) -> parent(y, z) ∨ ancestor(y, z) ∨ ¬parent(x, y) ∨ ancestor(x, z)
# Resolved parent(tom, bob) and ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬parent(x, y) ∨ ancestor(x, z) -> parent(x, y) ∨ ¬parent(y, z) ∨ ancestor(y, z) ∨ ancestor(x, z)
# Resolved parent(tom, bob) and ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬parent(y, z) ∨ ancestor(y, z) -> parent(z, z) ∨ ancestor(z, z) ∨ ¬parent(y, z) ∨ ancestor(y, z)
# Resolved parent(tom, bob) and ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬parent(y, z) ∨ ancestor(y, z) -> parent(y, z) ∨ ¬parent(z, z) ∨ ancestor(z, z) ∨ ancestor(y, z)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) -> parent(y, alice) ∨ ancestor(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬parent(y, y) ∨ ancestor(y, y) -> parent(y, y) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ancestor(y, y)
# Resolved parent(tom, bob) and ¬parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice) -> parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) -> parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice)
# Resolved parent(tom, bob) and ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬parent(y, alice) ∨ ancestor(y, alice) -> parent(y, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ ancestor(y, alice)
# Resolved parent(tom, bob) and ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(x, z) ∨ ancestor(x, z) ∨ ¬parent(x, z) -> parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(x, z) ∨ ancestor(x, z) ∨ ¬parent(x, z)
# Resolved parent(tom, bob) and ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(x, z) ∨ ancestor(x, z) ∨ ¬parent(x, z) -> parent(x, z) ∨ ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(x, z) ∨ ancestor(x, z)
# Resolved parent(tom, bob) and ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(y, y) ∨ ¬parent(y, y) -> parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(y, y) ∨ ¬parent(y, y)
# Resolved parent(tom, bob) and ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(y, y) ∨ ¬parent(y, y) -> parent(y, y) ∨ ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(y, y)
# Resolved parent(tom, bob) and ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ¬parent(z, z) ∨ ancestor(z, z) -> parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, z) ∨ ¬parent(z, z) ∨ ancestor(z, z)
# Resolved parent(tom, bob) and ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(y, z) ∨ ancestor(y, z) -> parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(y, z) ∨ ancestor(y, z)
# Resolved parent(tom, bob) and ¬parent(x, y) ∨ ancestor(x, y) ∨ ancestor(x, z) ∨ ¬parent(y, z) ∨ ¬ancestor(z, z) -> parent(y, z) ∨ ¬parent(x, y) ∨ ancestor(x, y) ∨ ancestor(x, z) ∨ ¬ancestor(z, z)
# Resolved parent(tom, bob) and ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬parent(y, z) -> parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬parent(y, z)
# Resolved parent(tom, bob) and ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(x, y) ∨ ancestor(x, z) ∨ ¬parent(y, z) -> parent(y, z) ∨ ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(x, y) ∨ ancestor(x, z)
# Resolved parent(tom, bob) and ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, y) ∨ ancestor(z, z) -> parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(z, y) ∨ ancestor(z, z)
# Resolved parent(tom, bob) and ¬parent(tom, bob) ∨ ¬ancestor(bob, z) ∨ ancestor(tom, z) -> ¬ancestor(bob, z) ∨ ancestor(tom, z)
# Resolved parent(tom, bob) and ¬parent(bob, z) ∨ ancestor(bob, z) ∨ ¬ancestor(z, z) -> parent(bob, z) ∨ ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(z, z)
# Resolved parent(tom, bob) and ¬parent(tom, bob) ∨ ¬ancestor(x, tom) ∨ ancestor(x, bob) -> ¬ancestor(x, tom) ∨ ancestor(x, bob)
# Resolved parent(tom, bob) and ¬parent(bob, alice) ∨ ancestor(bob, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(alice, z) ∨ ¬parent(alice, alice) -> parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(alice, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(alice, z)
# Resolved parent(tom, bob) and ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, z) ∨ ¬parent(z, alice) -> parent(z, alice) ∨ ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ¬ancestor(z, alice) ∨ ancestor(z, z)
# Resolved parent(tom, bob) and ¬parent(bob, alice) ∨ ancestor(bob, alice) ∨ ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) -> parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice)
# Resolved parent(tom, bob) and ¬parent(bob, alice) ∨ ancestor(bob, alice) ∨ ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice) ∨ ¬parent(alice, alice) -> parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(x, alice) ∨ ¬ancestor(alice, alice) ∨ ancestor(x, alice)
# Resolved parent(tom, bob) and ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ¬ancestor(alice, alice) ∨ ¬parent(alice, alice) -> parent(alice, alice) ∨ ¬parent(alice, z) ∨ ancestor(alice, z) ∨ ¬ancestor(alice, alice)
# Resolved parent(tom, bob) and ¬parent(x, x) ∨ ancestor(x, x) ∨ ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, alice) -> parent(x, x) ∨ ancestor(x, x) ∨ ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, alice)
# Resolved parent(tom, bob) and ¬parent(x, x) ∨ ancestor(x, x) ∨ ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice) ∨ ¬parent(x, alice) -> parent(x, alice) ∨ ¬parent(x, x) ∨ ancestor(x, x) ∨ ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice)
# Resolved parent(tom, bob) and ¬parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(x, tom) ∨ ancestor(x, alice) -> parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(x, tom) ∨ ancestor(x, alice)
# Resolved parent(tom, bob) and ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(alice, z) -> parent(alice, alice) ∨ ancestor(alice, alice) ∨ ¬ancestor(alice, z) ∨ ancestor(alice, z)
# Resolved parent(tom, bob) and ¬parent(x, x) ∨ ancestor(x, x) ∨ ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice) -> parent(x, x) ∨ ancestor(x, x) ∨ ¬ancestor(x, x) ∨ ¬ancestor(x, alice) ∨ ancestor(x, alice)
# Resolved parent(tom, bob) and ¬parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom) -> parent(tom, alice) ∨ ancestor(tom, alice) ∨ ¬ancestor(x, tom) ∨ ancestor(x, alice) ∨ ¬ancestor(tom, tom)
# Resolved parent(tom, bob) and ¬parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice) -> parent(tom, tom) ∨ ancestor(tom, tom) ∨ ¬ancestor(x, tom) ∨ ¬ancestor(tom, alice) ∨ ancestor(x, alice)
# Resolved parent(tom, bob) and ¬parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(y, y) ∨ ancestor(y, y) -> parent(y, alice) ∨ ancestor(y, alice) ∨ ¬ancestor(y, y) ∨ ancestor(y, y)
# Resolved parent(tom, bob) and ¬parent(x, y) ∨ ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z) -> parent(x, y) ∨ ancestor(x, y) ∨ ¬ancestor(y, z) ∨ ancestor(x, z)
# Resolved parent(tom, bob) and ¬parent(y, z) ∨ ancestor(y, z) ∨ parent(x, y) ∨ ancestor(x, z) -> parent(y, z) ∨ ancestor(y, z) ∨ parent(x, y) ∨ ancestor(x, z)
# Resolved parent(tom, bob) and ¬parent(z, z) ∨ ancestor(z, z) ∨ parent(y, z) ∨ ancestor(y, z) -> parent(z, z) ∨ ancestor(z, z) ∨ parent(y, z) ∨ ancestor(y, z)
# Resolved parent(tom, bob) and ¬parent(bob, alice) ∨ ancestor(bob, alice) ∨ parent(alice, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) -> parent(bob, alice) ∨ ¬parent(alice, alice) ∨ ancestor(alice, alice) ∨ parent(alice, alice)
# Resolved parent(tom, bob) and ¬parent(x, z) ∨ ancestor(x, z) ∨ ¬parent(x, y) ∨ ¬ancestor(y, z) -> parent(x, y) ∨ ¬parent(x, z) ∨ ancestor(x, z) ∨ ¬ancestor(y, z)
# Resolved parent(tom, bob) and ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(x, z) ∨ ¬parent(x, y) -> parent(x, y) ∨ ¬parent(y, z) ∨ ancestor(y, z) ∨ ¬ancestor(x, z)
# Resolved parent(tom, bob) and ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(y, z) ∨ ¬parent(y, z) -> parent(y, z) ∨ ¬parent(z, z) ∨ ancestor(z, z) ∨ ¬ancestor(y, z)
# Derived empty clause {} -> CONTRADICTION.
#
# Result: PROVED ✅
